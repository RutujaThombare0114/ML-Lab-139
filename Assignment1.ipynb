# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("wildfire.csv")

# %%
data.head()
# Out:
#    _id  OBJECTID         * Damage  * Street Number  * Street Name  \
# 0    1         1        No Damage           8376.0   Quail Canyon
# 1    2         2  Affected (1-9%)           8402.0   Quail Canyon
# 2    3         3        No Damage           8430.0  Quail Canyon
# 3    4         4        No Damage           3838.0    Putah Creek
# 4    5         5        No Damage           3830.0    Putah Creek
#
#   * Street Type (e.g. road, drive, lane, etc.)  \
# 0                                         Road
# 1                                         Road
# 2                                         Road
# 3                                         Road
# 4                                         Road
#
#   Street Suffix (e.g. apt. 23, blding C)   * City State  Zip Code  ...  \
# 0                                    NaN  Winters    CA       NaN  ...
# 1                                    NaN  Winters    CA       NaN  ...
# ...

# %%
data.tail()
# Out:
#            _id  OBJECTID   * Damage  * Street Number * Street Name  \
# 100225  100226    101217  No Damage          24198.0          Case
# 100226  100227    101218  No Damage          24198.0          Case
# 100227  100228    101219  No Damage          24198.0          Case
# 100228  100229    101220  No Damage          24008.0        Malibu
# 100229  100230    101221  No Damage          24016.0        Malibu
#
#        * Street Type (e.g. road, drive, lane, etc.)  \
# 100225                                        Court
# 100226                                        Court
# 100227                                        Court
# 100228                                         Road
# 100229                                         Road
#
#        Street Suffix (e.g. apt. 23, blding C)  * City State  Zip Code  ...  \
# 100225                               blding A  Malibu    CA   90265.0  ...
# 100226                               blding B  Malibu    CA   90265.0  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100230 entries, 0 to 100229
# Data columns (total 47 columns):
#  #   Column                                                        Non-Null Count   Dtype
# ---  ------                                                        --------------   -----
#  0   _id                                                           100230 non-null  int64
#  1   OBJECTID                                                      100230 non-null  int64
#  2   * Damage                                                      100230 non-null  object
#  3   * Street Number                                               95810 non-null   float64
#  4   * Street Name                                                 94744 non-null   object
#  5   * Street Type (e.g. road, drive, lane, etc.)                  87033 non-null   object
#  6   Street Suffix (e.g. apt. 23, blding C)                        44148 non-null   object
# ...

# %%
data.nunique()
# Out:
# _id                                                             100230
# OBJECTID                                                        100230
# * Damage                                                             6
# * Street Number                                                  18098
# * Street Name                                                     9818
# * Street Type (e.g. road, drive, lane, etc.)                        27
# Street Suffix (e.g. apt. 23, blding C)                            2260
# * City                                                             442
# State                                                                1
# Zip Code                                                           206
# * CAL FIRE Unit                                                     27
# County                                                              50
# Community                                                         1001
# ...

# %%
data.isnull().sum()
# Out:
# _id                                                                 0
# OBJECTID                                                            0
# * Damage                                                            0
# * Street Number                                                  4420
# * Street Name                                                    5486
# * Street Type (e.g. road, drive, lane, etc.)                    13197
# Street Suffix (e.g. apt. 23, blding C)                          56082
# * City                                                          31614
# State                                                               7
# Zip Code                                                        52801
# * CAL FIRE Unit                                                     0
# County                                                             30
# Community                                                       47338
# ...

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# _id                                                              0.000000
# OBJECTID                                                         0.000000
# * Damage                                                         0.000000
# * Street Number                                                  4.409857
# * Street Name                                                    5.473411
# * Street Type (e.g. road, drive, lane, etc.)                    13.166717
# Street Suffix (e.g. apt. 23, blding C)                          55.953307
# * City                                                          31.541455
# State                                                            0.006984
# Zip Code                                                        52.679836
# * CAL FIRE Unit                                                  0.000000
# County                                                           0.029931
# Community                                                       47.229372
# ...

# %%
data = data.drop(['_id'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100230 entries, 0 to 100229
# Data columns (total 46 columns):
#  #   Column                                                        Non-Null Count   Dtype
# ---  ------                                                        --------------   -----
#  0   OBJECTID                                                      100230 non-null  int64
#  1   * Damage                                                      100230 non-null  object
#  2   * Street Number                                               95810 non-null   float64
#  3   * Street Name                                                 94744 non-null   object
#  4   * Street Type (e.g. road, drive, lane, etc.)                  87033 non-null   object
#  5   Street Suffix (e.g. apt. 23, blding C)                        44148 non-null   object
#  6   * City                                                        68616 non-null   object
# ...

# %%
data.head()
# Out:
#    OBJECTID         * Damage  * Street Number  * Street Name  \
# 0         1        No Damage           8376.0   Quail Canyon
# 1         2  Affected (1-9%)           8402.0   Quail Canyon
# 2         3        No Damage           8430.0  Quail Canyon
# 3         4        No Damage           3838.0    Putah Creek
# 4         5        No Damage           3830.0    Putah Creek
#
#   * Street Type (e.g. road, drive, lane, etc.)  \
# 0                                         Road
# 1                                         Road
# 2                                         Road
# 3                                         Road
# 4                                         Road
#
#   Street Suffix (e.g. apt. 23, blding C)   * City State  Zip Code  \
# 0                                    NaN  Winters    CA       NaN
# 1                                    NaN  Winters    CA       NaN
# 2                                    NaN  Winters    CA       NaN
# ...

# %%
from datetime import datetime

# %%
data = pd.read_csv("wildfire.csv")
data["time"]=datetime.now()

# %%
#data['time_diff'] = datetime.now() - data['fire_time']
#print(data.head())
data.head()
# Out:
#    _id  OBJECTID         * Damage  * Street Number  * Street Name  \
# 0    1         1        No Damage           8376.0   Quail Canyon
# 1    2         2  Affected (1-9%)           8402.0   Quail Canyon
# 2    3         3        No Damage           8430.0  Quail Canyon
# 3    4         4        No Damage           3838.0    Putah Creek
# 4    5         5        No Damage           3830.0    Putah Creek
#
#   * Street Type (e.g. road, drive, lane, etc.)  \
# 0                                         Road
# 1                                         Road
# 2                                         Road
# 3                                         Road
# 4                                         Road
#
#   Street Suffix (e.g. apt. 23, blding C)   * City State  Zip Code  ...  \
# 0                                    NaN  Winters    CA       NaN  ...
# 1                                    NaN  Winters    CA       NaN  ...
# ...

# %%
data.shape
# Out:
# (100230, 48)

# %%
data.describe()
# Out:
#                  _id       OBJECTID  * Street Number      Zip Code  \
# count  100230.000000  100230.000000     9.581000e+04  47429.000000
# mean    50115.500000   50227.779717     3.886722e+04  46309.699973
# min         1.000000       1.000000     0.000000e+00      0.000000
# 25%     25058.250000   25058.250000     7.232500e+02      0.000000
# 50%     50115.500000   50115.500000     4.308500e+03      0.000000
# 75%     75172.750000   75172.750000     1.000300e+04  95667.000000
# max    100230.000000  101221.000000     1.410065e+09  96311.000000
# std     28934.053078   29107.678335     5.271695e+06  47467.653484
#
#        # Units in Structure (if multi unit)  \
# count                          31184.000000
# mean                               0.433299
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                             6101.000000
# ...

# %%
data.describe(include='all').T
# Out:
#                                                        count  unique  \
# _id                                                 100230.0     NaN
# OBJECTID                                            100230.0     NaN
# * Damage                                              100230       6
# * Street Number                                      95810.0     NaN
# * Street Name                                          94744    9818
# * Street Type (e.g. road, drive, lane, etc.)           87033      27
# Street Suffix (e.g. apt. 23, blding C)                 44148    2260
# * City                                                 68616     442
# State                                                 100223       1
# Zip Code                                             47429.0     NaN
# * CAL FIRE Unit                                       100230      27
# County                                                100200      50
# Community                                              52892    1001
# ...

# %%
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['_id', 'OBJECTID', '* Damage', '* Street Number', '* Street Name',
#        '* Street Type (e.g. road, drive, lane, etc.)',
#        'Street Suffix (e.g. apt. 23, blding C)', '* City', 'State', 'Zip Code',
#        '* CAL FIRE Unit', 'County', 'Community', 'Battalion',
#        '* Incident Name', 'Incident Number (e.g. CAAEU 123456)',
#        'Incident Start Date', 'Hazard Type',
#        'If Affected 1-9% - Where did fire start?',
#        'If Affected 1-9% - What started fire?',
#        'Structure Defense Actions Taken', '* Structure Type',
#        'Structure Category', '# Units in Structure (if multi unit)',
#        '# of Damaged Outbuildings < 120 SQFT',
#        '# of Non Damaged Outbuildings < 120 SQFT', '* Roof Construction',
#        '* Eaves', '* Vent Screen', '* Exterior Siding', '* Window Pane',
#        '* Deck/Porch On Grade', '* Deck/Porch Elevated',
#        '* Patio Cover/Carport Attached to Structure',
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, y='Assessed Improved Value (parcel)')
plt.title('Distribution of Assessed Improved Value')
plt.ylabel('Assessed Improved Value')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Year Built (parcel)'], bins=20, kde=True, color='blue')
plt.title('Year Built Distribution')
plt.xlabel('Year Built')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Longitude', y='Latitude', hue='* CAL FIRE Unit')
plt.title('Incident Locations by CAL FIRE Unit')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='CAL FIRE Unit')
plt.show()

# %%
hazard_counts = data['Hazard Type'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(hazard_counts, labels=hazard_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportions of Hazard Types')
plt.show()
