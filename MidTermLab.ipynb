# %%
#import library's and models

# %%
import numpy as np

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
#define datasets

# %%
x = np.array([50,55,10,20,35]).reshape(-1,1)

# %%
y = np.array([27,92,16,22,44])

# %%
#display datasets

# %%
x
# Out:
# array([[50],
#        [55],
#        [10],
#        [20],
#        [35]])

# %%
y
# Out:
# array([27, 92, 16, 22, 44])

# %%
#use linear regression model

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model = LinearRegression().fit(x,y)

# %%
#determine model score

# %%
rsq = model.score(x ,y)

# %%
print(f"model score is: {rsq}")
# Out:
# model score is: 0.5287075979040265

# %%
model.intercept_
# Out:
# 0.5102040816326578

# %%
model.coef_
# Out:
# array([1.16734694])

# %%
new_model = LinearRegression().fit(x ,y.reshape(-1 ,1))

# %%
new_model.coef_
# Out:
# array([[1.16734694]])

# %%
y_pred = model.predict(x)

# %%
x_new = np.arange(5).reshape(-1, 1)

# %%
x_new
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4]])

# %%
y_new = model.predict(x_new)

# %%
y_new
# Out:
# array([0.51020408, 1.67755102, 2.84489796, 4.0122449 , 5.17959184])

# %%
model.fit(x_new , y_new)
# Out:
# LinearRegression()
